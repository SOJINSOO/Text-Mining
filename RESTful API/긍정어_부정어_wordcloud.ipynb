# %% [markdown]
# # 긍정어 부정어 WordCloud

# %% [markdown]
# ### 필요한 패키지 import

# %%
import pandas as pd
from wordcloud import WordCloud
from collections import Counter
import matplotlib.pyplot as plt
import pickle
import time

# %% [markdown]
# ###  전처리된 음식점별 통합된 리뷰 DataFrame import

# %%
with open(r"C:\Users\SOJINSOO\여행고수\df_food_review.txt", "rb") as f: 
    df_food_review = pickle.load(f)

df_food_review
# Out:
#                                                   label  \
# 0                        055 Lobster Seafood Restaurant
# 1                               1 ping (Flagship Store)
# 2                      1010 Hunan Cuisine - Fubei Store
# 3             1010 Hunan Cuisine - Kaohsiung E-DA Store
# 4     1010 Hunan Cuisine - Nangang CTBC Financial Pa...
# 5               1010 Hunan Cuisine - Sinyi Eslite Store
# 6          1010 Hunan Cuisine - Taichung Parkland Store
# 7     1010 Hunan Cuisine - Tainan Ximen Mitsukoshi S...
# 8          1010 Hunan Cuisine - Tianmu Mitsukoshi Store
# 9                       1010 Hunan Cuisine - Xihu Store
# 10                   1010 Hunan Cuisine - Xindian Store
# 11            1010 Hunan Cuisine - Xizhi Farglory Store
# 12                                            11 Social
# 13                                            12 Basket
# 14                            12HOTPOT - Fengshan Wujia
# 15                         12HOTPOT - Fengyuan Yuanfeng
# 16                          12HOTPOT - Kaohsiung Sanduo
# 17                        12HOTPOT - Qingshui Zhongshan
# 18                           12HOTPOT - Rende Zhongshan
# 19               12HOTPOT - Sanchong Carrefour Chongxin
# 20                            12HOTPOT - Taichung Henan
# 21                         12HOTPOT - Taichung Zhonghua
# 22                   12HOTPOT - Taipei Carrefour Guilin
# 23                        12HOTPOT - Taipei MRT Jingmei
# 24                  12HOTPOT - Taipei Minquan Longjiang
# 25                              12HOTPOT - Taipei Xinyi
# 26                           12HOTPOT - Taoyuan Nanping
# 27                         12HOTPOT - Xinzhuang MRT FJU
# 28            12HOTPOT - Zhongli Carrefour Zhongshan E.
# 29                          12HOTPOT - Zhongli Zhongmei
# ...                                                 ...
# 3989      maidreamin Akihabara Electric Town-Exit Store
# 3990             maidreamin Akihabara Idol Street Store
# 3991                                 maidreamin SHIBUYA
# 3992                 san Shang Qiao Fu - Fengyuan Store
# 3993                  si liang qian jin huo xia zhi jia
# 3994                                         solo pasta
# 3995                                 the Diner Nan'gang
# 3996                                   the Diner- Ruian
# 3997                                               zuma
# 3998                                   교토 기온 텐푸라 야사카 엔도
# 3999                                                나탄즈
# 4000                                               뉴욕 바
# 4001                                                 닌자
# 4002                                   더 리플렉시언즈 - 운영 종료
# 4003                         르 노르망디 레스토랑 앳 만다린 오리엔탈, 방콕
# 4004                                             무사시 스시
# 4005                                  미트러브 한식참숯구이 타이페이점
# 4006                                               소메타로
# 4007                                           시로코 레스토랑
# 4008                                           시암 수퍼 클럽
# 4009                                           신주쿠 츠나하치
# 4010                                               얌 타이
# 4011                                                이찌란
# 4012                                         인디안 바이 네이처
# 4013                                          철판 베이 신주쿠
# 4014                                               카이카야
# 4015                                         카츠쿠라 산죠 본점
# 4016                                                큐베이
# 4017                                         타파스 몰레큘러 바
# 4018                                        프랑스 국민 레스토랑
#
#                                                 content   country
# 0     use option near sea close food fantastic unfor...    taiwan
# 1     nan nan nan nan nan nan nan nan nan nan nan na...    taiwan
# 2     second month row selected hunan dinner fuxing ...    taiwan
# 3     amount la carte xiang restaurant relatively sm...    taiwan
# 4     taste spicy good service good atmosphere come ...    taiwan
# 5     due advance reservations take place quickly se...    taiwan
# 6     general enter restaurant chain desperate expec...    taiwan
# 7     food place miss preserved pepper eggs also ord...    taiwan
# 8     first time ate restaurant environment comforta...    taiwan
# 9     xiangxi lake restaurant restaurant like much t...    taiwan
# 10    first time using eztable app convenient day me...    taiwan
# 11    everyone delicious good us food parents happy ...    taiwan
# 12    cream brittany different perry perry chicken l...    taiwan
# 13    listening friend introduction came twelve bask...    taiwan
# 14    live nearby eat every three five lot people ta...    taiwan
# 15    delicate delicious hot pot dishes time choose ...    taiwan
# 16    shi erguo wangpin group price low ingredients ...    taiwan
# 17    km qingshui railway station good atmosphere ch...    taiwan
# 18    affordable eat everyone eat drink drink price ...    taiwan
# 19    restaurant quite hygienic cheap hot pot restau...    taiwan
# 20    wanted eat hot pot noon checked online decided...    taiwan
# 21    cheap hot pot restaurant although place taichu...    taiwan
# 22    recommended driver seokgi taxi tours located t...    taiwan
# 23    price cheap price cp value high good place sud...    taiwan
# 24    dine friends near zhongshan junior high school...    taiwan
# 25    super favorite also portion enough choose whet...    taiwan
# 26    chain hot pot restaurants many soup bases ston...    taiwan
# 27    always heard good hot pot restaurant good pric...    taiwan
# 28    cold weather grand occasion long queues hahaha...    taiwan
# 29    restaurant located zhongmei village food gathe...    taiwan
# ...                                                 ...       ...
# 3989  watch live shop staff lively say lot things me...     japan
# 3990  went maid caf went korea know japanese set men...     japan
# 3991  staff professional better expect food drink li...     japan
# 3992  sanshang qiaofu chain restaurant restaurant ai...    taiwan
# 3993  food delicious space spacious comfortable park...    taiwan
# 3994  food plain exceptional appetizers honestly emb...    taiwan
# 3995  go seat need relax asian food usually order sa...    taiwan
# 3996  brunch restaurant weekend lunch lot people bit...    taiwan
# 3997  international franchise restaurant zone sushi ...      thai
# 3998  right hungry fried tempura crisp visited vario...     japan
# 3999  place visit every year christophe kind atmosph...      thai
# 4000  lost translation awesome atmosphere service li...     japan
# 4001  came accident last day trip akasaka food cours...     japan
# 4002  rather expensive meal compared bangkok waterfr...      thai
# 4003  french restaurant mandarin oriental hotel mich...      thai
# 4004  sushi diverse quality good waiting line missin...     japan
# 4005  want experience popular korean barbecue xinyi ...    taiwan
# 4006  famous house long queue opening clock hall fil...     japan
# 4007  lot visited lot monkeys also fall trees dress ...      thai
# 4008  several restaurants around one honestly atmosp...      thai
# 4009  tempura restaurant shinjuku tempura thin price...     japan
# 4010  fried rice spring roll yum yum yum delicious a...      thai
# 4011  fukuoka tokyo three times service friendly tas...     japan
# 4012  nice dinner celebrate th anniversary second tr...      thai
# 4013  ate one seafood three famous ones went well be...     japan
# 4014  shibuya japanese seafood izakaya located quiet...     japan
# 4015  korean menu price around yen failure famous po...     japan
# 4016  introduced tripadvisor visited staff really po...     japan
# 4017  best meal since narisawa saying lot think expl...     japan
# 4018  important note location bit far city traffic h...  cambodia
#
# [4019 rows x 3 columns]

# %% [markdown]
# ### 감성사전 load

# %%
from afinn import Afinn

afinn = Afinn()

# %% [markdown]
# ### 긍부정 WordCloud 객체 생성 및 레이아웃 설정

# %%
wordcloud_neg = WordCloud(
    width = 800,
    height = 800,
    background_color = "Black", colormap="Reds"
)

wordcloud_pos = WordCloud(
    width = 800,
    height = 800,
    background_color = "White", colormap="Blues"
)

# %% [markdown]
# ### numpy array로 변환

# %%
def __array__(self):
    """Convert to numpy array.
    Returns
    -------
    image : nd-array size (width, height, 3)
        Word cloud image as numpy matrix.
    """
    return self.to_array()

def to_array(self):
    """Convert to numpy array.
    Returns
    -------
    image : nd-array size (width, height, 3)"
        Word cloud image as numpy matrix.
    """
    return np.array(self.to_image())

# %% [markdown]
# ### 식당별 긍정 어휘, 부정 어휘 WordCloud Image생성

# %%
for i in range(len(df_food_review)):
    # 해당 식당의 감성 어휘 및 극성 DataFrame
    df_afinn = pd.DataFrame(list(zip(afinn.find_all(df_food_review['content'][i]), afinn.scores_with_pattern(df_food_review['content'][i]))), 
                            columns = ['word', 'polarity']) 
    
    # 부정 어휘 DataFrame
    df_result_neg = df_afinn[df_afinn['polarity'].isin(['-5', '-4', '-3', '-2', '-1'])]
    # 긍정 어휘 DataFrame
    df_result_pos = df_afinn[df_afinn['polarity'].isin(['1', '2', '3', '4', '5'])]
    
    # 긍정, 부정 어휘 빈도분석
    count_neg = Counter(df_result_neg['word'])
    count_pos = Counter(df_result_pos['word'])
    
    # WordCloud
    try:
        # 긍정, 부정 WordCloud 생성
        wordcloud_neg = wordcloud_neg.generate_from_frequencies(count_neg)
        wordcloud_pos = wordcloud_pos.generate_from_frequencies(count_pos)
        
        # 긍정 부정 WordCloud 객체를 numpy array로 변환
        array_neg = wordcloud_neg.to_array()
        array_pos = wordcloud_pos.to_array()
        
        # 긍정 어휘 WordCloud Image 생성 및 저장
        # %matplotlib inline

        fig = plt.figure(figsize=(10,10))
        plt.imshow(array_pos, interpolation="bilinear")  # 보간법 = 쌍선형 보간법
        plt.show()    
        fig.savefig('C:\\Users\SOJINSOO\\여행고수\긍정어_wordcloud\\' + str(df_food_review['country'][i]) + '\\' + str(df_food_review['label'][i]) + '.png')
        
        # 주정 어휘 WordCloud Image 생성 및 저장
        # %matplotlib inline
    
        fig = plt.figure(figsize=(10,10))
        plt.imshow(array_neg, interpolation="bilinear")  # 보간법 = 쌍선형 보간법
        plt.show()    
        fig.savefig('C:\\Users\SOJINSOO\\여행고수\부정어_wordcloud\\' + str(df_food_review['country'][i]) + '\\' + str(df_food_review['label'][i]) + '.png')   
    
        plt.close(fig)
        print(i)
    except: pass
